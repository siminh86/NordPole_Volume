# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_date = pd.read_excel("DateInOneYear.xlsx", header=None)
RevisedDate = df_date[0]
RevisedDate.shape
# Out:
# (8785,)

# %%
df = pd.read_excel("xlsx_Files/01. elspot-volumes_2013_hourly.xlsx", header = 2)
df['Date_daily'] = RevisedDate
df
# Out:
#                Date_daily    Hours Turnover at system price NO1 Buy NO1 Sell  \
# 0     2013-01-01 00:00:00  00 - 01                  33999,0  4060,2   2537,6
# 1     2013-01-01 00:00:00  01 - 02                  33050,9  3967,3   2475,7
# 2     2013-01-01 00:00:00  02 - 03                  32363,8  3861,2   2385,3
# 3     2013-01-01 00:00:00  03 - 04                  31849,0  3766,6   2323,7
# 4     2013-01-01 00:00:00  04 - 05                  31871,9  3742,0   2208,1
# 5     2013-01-01 00:00:00  05 - 06                  32323,4  3787,5   2109,6
# 6     2013-01-01 00:00:00  06 - 07                  33277,1  3959,5   2207,2
# 7     2013-01-01 00:00:00  07 - 08                  34209,6  4123,9   2355,5
# 8     2013-01-01 00:00:00  08 - 09                  34713,7  4156,5   2328,9
# 9     2013-01-01 00:00:00  09 - 10                  35410,4  4225,1   2396,5
# 10    2013-01-01 00:00:00  10 - 11                  36609,8  4476,3   2630,0
# ...

# %%
df.shape
# Out:
# (8761, 35)

# %%
X = df['Date_daily']
SE1_Buy = df['SE1 Buy']
SE1_Sell = df['SE1 Sell']

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(20, 10), dpi=80, facecolor='w', edgecolor='k')

plt.plot(X,SE1_Buy)
plt.plot(X,SE1_Sell)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-9f8ea0b888ea> in <module>()
#       2 figure(num=None, figsize=(20, 10), dpi=80, facecolor='w', edgecolor='k')
#       3
# ----> 4 plt.plot(X,SE1_Buy)
#       5 plt.plot(X,SE1_Sell)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(*args, **kwargs)
#    3361                       mplDeprecation)
#    3362     try:
# -> 3363         ret = ax.plot(*args, **kwargs)
#    3364     finally:
#    3365         ax._hold = washold
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1865                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1866                         RuntimeWarning, stacklevel=2)
# -> 1867             return func(ax, *args, **kwargs)
#    1868
# ...
