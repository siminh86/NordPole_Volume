# %%
#import required python packages
import datetime
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd

# %%
func = pd.read_excel('2019Volume.xlsx', parse_dates=True, na_values=-1)


func.head(10)
# Out:
# /Users/simin/anaconda3/lib/python3.6/site-packages/pandas/io/excel.py:351: UserWarning: The 'parse_dates=True' keyword of read_excel was provided without an 'index_col' keyword value.
#   warn("The 'parse_dates=True' keyword of read_excel was provided"
#         Date Turnover at system price   NO1 Buy NO1 Sell   NO2 Buy  NO2 Sell  \
# 0 2019-01-01                 962979,3  117113,9  36893,1  101671,6   95138,0
# 1 2019-01-02                1159437,5  138160,7  41818,1  114813,9  134716,3
# 2 2019-01-03                1256698,7  135422,6  47680,0  118955,3  163173,1
# 3 2019-01-04                1166200,5  125737,4  39853,8  114148,9  138564,2
# 4 2019-01-05                1118875,1  107772,5  40112,7  108807,0  146128,6
# 5 2019-01-06                1126034,0  110803,8  40306,8  108948,3  153373,2
# 6 2019-01-07                1213829,1  145644,1  57252,1  115969,0  165046,5
# 7 2019-01-08                1171011,5  147756,3  52106,2  109894,0  135938,9
# 8 2019-01-09                1207202,1  151183,7  53016,6  118352,2  154202,3
# 9 2019-01-10                1272869,6  156276,4  58341,6  121379,0  180846,2
#
#    NO3 Buy NO3 Sell  NO4 Buy NO4 Sell   ...     DK1 Buy DK1 Sell  DK2 Buy  \
# 0  77547,3  55707,9  47729,8  32519,2   ...     35378,6  83233,3  26206,4
# 1  85246,1  65215,6  52813,6  57187,3   ...     52203,5  77572,9  36449,1
# 2  83231,6  76809,2  50525,5  70498,8   ...     71610,4  64639,8  45607,7
# 3  81320,0  72474,7  48673,7  64103,6   ...     40871,3  81467,4  39955,3
# 4  78296,5  67563,8  46843,6  66781,1   ...     49192,1  67330,9  38477,3
# 5  76573,3  70296,3  46289,6  74078,9   ...     60282,8  52484,7  44481,4
# 6  82741,5  69262,8  49602,3  66964,7   ...     50632,6  70302,6  42963,1
# 7  83350,5  69605,2  49047,5  55535,1   ...     35059,9  90082,7  35197,8
# 8  85301,2  69029,2  49721,7  64988,6   ...     39690,7  83520,8  36394,0
# 9  84192,7  76481,2  45150,7  75566,6   ...     69085,8  60820,8  41883,5
#
#   DK2 Sell   EE Buy  EE Sell   LV Buy  LV Sell   LT Buy  LT Sell
# 0  39680,1  19671,2  16915,0  20882,6   9939,0  30864,8  41499,9
# 1  37188,5  23760,0  21870,0  20755,2  13790,4  37286,6  46785,0
# 2  27492,6  24150,0  22507,5  22100,1  19033,7  40480,2  44750,8
# 3  34127,7  25552,9  22880,5  22486,7  16980,7  44999,9  32741,8
# 4  30062,4  24064,7  20509,0  20306,2  14356,3  38638,6  35893,2
# 5  21383,1  24044,7  22557,8  20595,6  15847,9  36410,8  32177,8
# 6  28755,3  25936,5  28787,8  23288,1  16778,1  46644,9  28661,1
# 7  41147,0  26000,2  26579,0  23892,9  15565,0  44935,3  31884,1
# 8  38717,5  27152,2  26811,2  24438,1  20896,8  47286,9  26166,6
# 9  24982,0  27028,7  35400,6  24667,6  24229,2  44784,6  26919,4
#
# [10 rows x 34 columns]

# %%
func_sell = func['SE1 Sell']
func_buy = func['SE1 Buy']

# %%
func.shape
# Out:
# (171, 34)

# %%
func.describe()
# Out:
#                        Date Turnover at system price  NO1 Buy NO1 Sell  \
# count                   171                      171      171      171
# unique                  171                      171      171      171
# top     2019-01-21 00:00:00                 919674,5  68360,0  68219,8
# freq                      1                        1        1        1
# first   2019-01-01 00:00:00                      NaN      NaN      NaN
# last    2019-06-20 00:00:00                      NaN      NaN      NaN
#
#          NO2 Buy NO2 Sell  NO3 Buy NO3 Sell  NO4 Buy NO4 Sell   ...     \
# count        171      171      171      171      171      171   ...
# unique       171      171      171      171      171      171   ...
# top     101572,1  58706,3  91872,3  54648,8  55161,7  79481,7   ...
# freq           1        1        1        1        1        1   ...
# first        NaN      NaN      NaN      NaN      NaN      NaN   ...
# last         NaN      NaN      NaN      NaN      NaN      NaN   ...
#
#         DK1 Buy DK1 Sell  DK2 Buy DK2 Sell   EE Buy  EE Sell   LV Buy  \
# count       171      171      171      171      171      171      171
# unique      171      171      171      171      171      171      171
# top     64383,9  49428,2  39711,2  24982,0  18836,5  15143,2  19588,2
# freq          1        1        1        1        1        1        1
# first       NaN      NaN      NaN      NaN      NaN      NaN      NaN
# last        NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#         LV Sell   LT Buy  LT Sell
# count       171      171      171
# unique      170      170      171
# top     23890,6  42278,3  50637,8
# freq          2        2        1
# first       NaN      NaN      NaN
# last        NaN      NaN      NaN
#
# [6 rows x 34 columns]

# %%
x = func['Date']

y = func['SE1 Sell']


Z = func['SE1 Buy']

type(x)
# Out:
# pandas.core.series.Series

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(20, 10), dpi=80, facecolor='w', edgecolor='k')

plt.plot(x,y)
plt.plot(x,Z)
