# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn
import matplotlib
import numpy

import matplotlib.dates as mdates

# %%
func = pd.read_excel('2019Volume.xlsx')
dates = matplotlib.dates.date2num(func['Date'])
func.head(3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-67-2daf09283362> in <module>()
#       1 func = pd.read_excel('2019Volume.xlsx')
# ----> 2 dates = matplotlib.dates.date2num(func['Date'])
#       3 func.head(3)
#
# /Users/simin/anaconda3/lib/python3.6/site-packages/matplotlib/dates.py in date2num(d)
#     371         if not d.size:
#     372             return d
# --> 373         return _to_ordinalf_np_vectorized(d)
#     374
#     375
#
# /Users/simin/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py in __call__(self, *args, **kwargs)
#    2737             vargs.extend([kwargs[_n] for _n in names])
#    2738
# -> 2739         return self._vectorize_call(func=func, args=vargs)
#    2740
#    2741     def _get_ufunc_and_otypes(self, func, args):
#
# /Users/simin/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py in _vectorize_call(self, func, args)
#    2807             res = func()
#    2808         else:
# -> 2809             ufunc, otypes = self._get_ufunc_and_otypes(func=func, args=args)
#    2810
#    2811             # Convert args to object arrays first
#
# /Users/simin/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py in _get_ufunc_and_otypes(self, func, args)
#    2767
#    2768             inputs = [arg.flat[0] for arg in args]
# -> 2769             outputs = func(*inputs)
#    2770
#    2771             # Performance note: profiling indicates that -- for simple
#
# /Users/simin/anaconda3/lib/python3.6/site-packages/matplotlib/dates.py in _to_ordinalf(dt)
#     220         tzi = UTC
#     221
# --> 222     base = float(dt.toordinal())
#     223
#     224     # If it's sufficiently datetime-like, it will have a `date()` method
#
# AttributeError: 'numpy.datetime64' object has no attribute 'toordinal'

# %%
func_sell = func['SE1 Sell']
func_buy = func['SE1 Buy']

# %%
func.shape
# Out:
# (171, 34)

# %%
func.describe()
# Out:
#                        Date Turnover at system price  NO1 Buy NO1 Sell  \
# count                   171                      171      171      171
# unique                  171                      171      171      171
# top     2019-08-02 00:00:00                 919674,5  68360,0  68219,8
# freq                      1                        1        1        1
# first   2019-01-01 00:00:00                      NaN      NaN      NaN
# last    2019-12-06 00:00:00                      NaN      NaN      NaN
#
#          NO2 Buy NO2 Sell  NO3 Buy NO3 Sell  NO4 Buy NO4 Sell   ...     \
# count        171      171      171      171      171      171   ...
# unique       171      171      171      171      171      171   ...
# top     101572,1  58706,3  91872,3  54648,8  55161,7  79481,7   ...
# freq           1        1        1        1        1        1   ...
# first        NaN      NaN      NaN      NaN      NaN      NaN   ...
# last         NaN      NaN      NaN      NaN      NaN      NaN   ...
#
#         DK1 Buy DK1 Sell  DK2 Buy DK2 Sell   EE Buy  EE Sell   LV Buy  \
# count       171      171      171      171      171      171      171
# unique      171      171      171      171      171      171      171
# top     64383,9  49428,2  39711,2  24982,0  18836,5  15143,2  19588,2
# freq          1        1        1        1        1        1        1
# first       NaN      NaN      NaN      NaN      NaN      NaN      NaN
# last        NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#         LV Sell   LT Buy  LT Sell
# count       171      171      171
# unique      170      170      171
# top     23890,6  42278,3  50637,8
# freq          2        2        1
# first       NaN      NaN      NaN
# last        NaN      NaN      NaN
#
# [6 rows x 34 columns]

# %%
X = func['Date']
Y = func['SE1 Sell']
Z = func['SE1 Buy']

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(20, 10), dpi=80, facecolor='w', edgecolor='k')

plt.plot(X,Y)
plt.plot_date(X,Z)
plt.title('2019')
plt.savefig('01.jpg')

# %%
# plot
mdates.(X,Y)
# beautify the x-labels
plt.gcf().autofmt_xdate()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-73-184cb47272de> in <module>()
#       1 # plot
# ----> 2 mdates.plt(X,Y)
#       3 # beautify the x-labels
#       4 plt.gcf().autofmt_xdate()
#
# AttributeError: module 'matplotlib.dates' has no attribute 'plt'
