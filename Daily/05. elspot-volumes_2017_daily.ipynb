# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Importing 365 days in a year
df_date = pd.read_excel("DateInOneYear.xlsx", sheetname = '2017', header=None)
RevisedDate = df_date[0]
RevisedDate.shape
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\excel.py:329: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   **kwds)
# (365,)

# %%
df = pd.read_excel("05. elspot-volumes_2017_daily.xlsx")
df['Date_daily'] = RevisedDate
df.tail(5)
# Out:
#     Date_daily Turnover at system price   NO1 Buy NO1 Sell   NO2 Buy  \
# 360 2017-12-27                1195254,3  140981,3  51501,2  125038,8
# 361 2017-12-28                1206997,7  135347,2  51470,6  126324,5
# 362 2017-12-29                1164593,3  134757,9  47614,9  128810,1
# 363 2017-12-30                1109233,3  139039,4  43378,6  125989,9
# 364 2017-12-31                1074501,4  134988,9  44924,8  119022,1
#
#      NO2 Sell  NO3 Buy NO3 Sell  NO4 Buy NO4 Sell   ...     DK1 Buy DK1 Sell  \
# 360  187610,7  77958,7  61852,1  51663,3  70298,5   ...     64482,1  53024,5
# 361  199429,6  81477,6  65292,6  52155,8  77510,4   ...     61941,2  46493,2
# 362  188844,1  80902,8  57344,0  51757,1  68117,6   ...     45037,4  59725,8
# 363  162935,5  78898,0  47128,7  48458,3  49452,4   ...     34121,5  92133,1
# 364  150570,5  75813,4  43380,5  47296,4  47050,3   ...     32957,3  87703,5
#
#      DK2 Buy DK2 Sell   EE Buy  EE Sell   LV Buy  LV Sell   LT Buy  LT Sell
# 360  44010,6  24344,4  22485,3  27687,3  21428,9  20126,7  39626,8  15278,5
# 361  42621,2  21568,7  21960,1  27837,0  21246,9  23655,2  37858,6  21286,8
# 362  37516,5  33269,7  21201,0  26780,0  20677,6  22488,3  40923,1  15933,0
# 363  31052,5  38990,3  19936,4  19802,1  19289,5  25958,9  36239,3  16109,5
# 364  31663,9  35936,6  19928,9  20269,0  18795,1  24233,8  34483,9  20026,1
#
# [5 rows x 34 columns]

# %%
df.shape
# Out:
# (365, 34)

# %%
X = df['Date_daily']
SE1_Buy = df['SE1 Buy']
SE1_Sell = df['SE1 Sell']

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(20, 10), dpi=80, facecolor='w', edgecolor='k')

plt.plot(X,SE1_Buy)
plt.plot(X,SE1_Sell)

# %%
SE2_Buy = df['SE2 Buy']
SE2_Sell = df['SE2 Sell']

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(20, 10), dpi=80, facecolor='w', edgecolor='k')

plt.plot(X,SE2_Buy)
plt.plot(X,SE2_Sell)

# %%
SE3_Buy = df['SE3 Buy']
SE3_Sell = df['SE3 Sell']

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(20, 10), dpi=80, facecolor='w', edgecolor='k')

plt.plot(X,SE3_Buy)
plt.plot(X,SE3_Sell)

# %%
SE4_Buy = df['SE4 Buy']
SE4_Sell = df['SE4 Sell']

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(20, 10), dpi=80, facecolor='w', edgecolor='k')

plt.plot(X,SE4_Buy)
plt.plot(X,SE4_Sell)
