# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Importing 365 days in a year
df_date = pd.read_excel("DateInOneYear.xlsx", header=None)
RevisedDate = df_date[0]
RevisedDate.shape
# Out:
# (365,)

# %%
df = pd.read_excel("06. elspot-volumes_2018_daily.xlsx")
df['Date_daily'] = RevisedDate
df.tail(5)
# Out:
#     Date_daily Turnover at system price   NO1 Buy NO1 Sell   NO2 Buy  \
# 360 2013-12-27                1160518,1  136251,2  38485,7  118186,0
# 361 2013-12-28                1175640,1  130866,0  40572,7  118163,0
# 362 2013-12-29                1080067,8  126514,1  36555,0  115298,9
# 363 2013-12-30                1100305,9  129085,2  38155,4  116538,9
# 364 2013-12-31                1091333,6  123778,3  37070,9  111439,7
#
#      NO2 Sell  NO3 Buy NO3 Sell  NO4 Buy NO4 Sell   ...     DK1 Buy DK1 Sell  \
# 360  154482,1  82224,6  60845,5  49173,9  62991,3   ...     53957,4  57556,0
# 361  166129,4  82752,7  69169,7  48917,8  69538,7   ...     63316,1  55510,5
# 362  122147,9  79974,4  59631,6  47029,6  54592,8   ...     38825,1  64700,5
# 363  127707,8  80602,6  55758,0  49039,9  57907,3   ...     40858,3  68117,6
# 364  115364,8  79202,9  60983,7  48885,2  45405,1   ...     49307,2  61390,7
#
#      DK2 Buy DK2 Sell   EE Buy  EE Sell   LV Buy  LV Sell   LT Buy  LT Sell
# 360  43329,4  30251,7  23333,8  15115,8  21622,2  13531,0  37509,0  27569,0
# 361  46216,7  23850,5  23307,3  16090,3  21385,0  14019,7  39323,3  28202,4
# 362  38201,8  32550,9  21841,4  16207,1  19640,3  13656,5  36072,0  28679,2
# 363  34835,0  35051,2  21431,5  14447,7  19130,2  13912,2  35154,1  33616,1
# 364  43961,8  24989,7  21750,0  16501,3  19223,6  15897,6  39277,4  36825,3
#
# [5 rows x 34 columns]

# %%
df.shape
# Out:
# (365, 34)

# %%
X = df['Date_daily']
Y1 = df['SE1 Buy']
Y2 = df['SE1 Sell']

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(20, 10), dpi=80, facecolor='w', edgecolor='k')

plt.plot(X,Y1)
plt.plot(X,Y2)

# %%
X = df['Date_daily']
Y1 = df['SE2 Buy']
Y2 = df['SE2 Sell']

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(20, 10), dpi=80, facecolor='w', edgecolor='k')

plt.plot(X,Y1)
plt.plot(X,Y2)

# %%
X = df['Date_daily']
Y1 = df['SE3 Buy']
Y2 = df['SE3 Sell']

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(20, 10), dpi=80, facecolor='w', edgecolor='k')

plt.plot(X,Y1)
plt.plot(X,Y2)

# %%
X = df['Date_daily']
Y1 = df['SE4 Buy']
Y2 = df['SE4 Sell']

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(20, 10), dpi=80, facecolor='w', edgecolor='k')

plt.plot(X,Y1)
plt.plot(X,Y2)
