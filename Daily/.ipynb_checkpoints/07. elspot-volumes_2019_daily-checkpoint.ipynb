# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Importing 365 days in a year
df_date = pd.read_excel("DateInOneYear.xlsx", sheetname = '2019', header=None)
RevisedDate = df_date[0]
RevisedDate.shape
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\excel.py:329: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   **kwds)
# (174,)

# %%
df = pd.read_excel("07. elspot-volumes_2019_daily.xlsx")
df['Date_daily'] = RevisedDate
df.tail(5)
# Out:
#     Date_daily Turnover at system price  NO1 Buy NO1 Sell   NO2 Buy NO2 Sell  \
# 169 2019-06-19                 902952,6  65206,1  68219,8  100891,1  84501,5
# 170 2019-06-20                 894585,0  65339,7  66909,4  101302,6  82487,0
# 171 2019-06-21                 851465,1  63180,3  62379,9  101628,1  79390,1
# 172 2019-06-22                 794321,8  55965,3  59237,2   90205,1  57921,5
# 173 2019-06-23                 784240,0  55487,4  52417,7   99583,4  46955,8
#
#      NO3 Buy NO3 Sell  NO4 Buy NO4 Sell   ...     DK1 Buy DK1 Sell  DK2 Buy  \
# 169  67872,6  64431,7  36959,0  46589,2   ...     56912,8  18139,5  36374,8
# 170  66077,1  64605,4  35514,7  44268,0   ...     64701,3  24869,4  36251,8
# 171  65594,7  54365,1  34871,4  39328,2   ...     67662,2  25875,0  39767,4
# 172  62693,4  53786,3  34240,5  30611,5   ...     53306,8  18440,9  34527,0
# 173  63190,1  51934,5  33761,1  34915,8   ...     38439,0  32361,7  27548,5
#
# ...

# %%
df.shape
# Out:
# (174, 34)

# %%
X = df['Date_daily']
SE1_Buy = df['SE1 Buy']
SE1_Sell = df['SE1 Sell']

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(20, 10), dpi=80, facecolor='w', edgecolor='k')

plt.plot(X,SE1_Buy)
plt.plot(X,SE1_Sell)

# %%
SE2_Buy = df['SE2 Buy']
SE2_Sell = df['SE2 Sell']

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(20, 10), dpi=80, facecolor='w', edgecolor='k')

plt.plot(X,SE2_Buy)
plt.plot(X,SE2_Sell)

# %%
SE3_Buy = df['SE3 Buy']
SE3_Sell = df['SE3 Sell']

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(20, 10), dpi=80, facecolor='w', edgecolor='k')

plt.plot(X,SE3_Buy)
plt.plot(X,SE3_Sell)

# %%
SE4_Buy = df['SE4 Buy']
SE4_Sell = df['SE4 Sell']

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(20, 10), dpi=100, facecolor='w', edgecolor='k')

plt.plot(X,SE4_Buy)
plt.plot(X,SE4_Sell)
