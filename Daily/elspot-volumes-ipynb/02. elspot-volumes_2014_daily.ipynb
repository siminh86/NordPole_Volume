# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Importing 365 days in a year
df_date = pd.read_excel("DateInOneYear.xlsx", sheetname='2014', header=None)
RevisedDate = df_date[0]
RevisedDate.shape
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\excel.py:329: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   **kwds)
# (365,)

# %%
df = pd.read_excel("02. elspot-volumes_2014_daily.xlsx")
df['Date_daily'] = RevisedDate
df.tail(5)
# Out:
#     Date_daily Turnover at system price   NO1 Buy NO1 Sell   NO2 Buy  \
# 360 2014-12-27                1143994,3  146792,3  53331,5  121475,7
# 361 2014-12-28                1177521,7  144006,2  53876,5  121737,5
# 362 2014-12-29                1243569,2  149704,3  59212,9  129679,1
# 363 2014-12-30                1180037,5  147228,4  57075,2  131267,1
# 364 2014-12-31                1047169,1  133623,2  54341,3  122123,1
#
#      NO2 Sell  NO3 Buy NO3 Sell  NO4 Buy NO4 Sell   ...     DK1 Buy DK1 Sell  \
# 360  198308,9  69647,0  39191,4  52094,0  73092,9   ...     40971,6  61060,5
# 361  208104,7  67469,0  43271,2  51632,9  77202,2   ...     49743,1  49235,4
# 362  209273,8  66397,0  53685,6  53345,6  83456,6   ...     51697,2  61156,8
# 363  198752,3  65383,4  48281,8  50433,9  70271,2   ...     40454,0  52217,7
# 364  166298,9  60145,5  37617,2  47142,6  47815,5   ...     32908,9  54470,2
#
#      DK2 Buy DK2 Sell   EE Buy  EE Sell   LV Buy  LV Sell   LT Buy  LT Sell
# 360  36506,0  32600,1  21506,8  25230,1  20353,9   6682,0  26324,1  19932,6
# 361  42479,1  27617,7  21409,0  24884,4  20014,2   6276,3  26931,9  20995,7
# 362  46337,4  25959,5  24416,5  27411,6  23004,2  19599,5  28235,3  19520,7
# 363  47139,4  27125,2  23127,2  28063,1  22456,9  15377,2  31857,8  21634,7
# 364  42273,9  29070,1  20659,7  28431,8  20492,5  14680,0  31310,4  18377,7
#
# [5 rows x 32 columns]

# %%
df.shape
# Out:
# (365, 32)

# %%
X = df['Date_daily']
SE1_Buy = df['SE1 Buy']
SE1_Sell = df['SE1 Sell']

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(20, 10), dpi=80, facecolor='w', edgecolor='k')

plt.plot(X,SE1_Buy)
plt.plot(X,SE1_Sell)

# %%
SE2_Buy = df['SE2 Buy']
SE2_Sell = df['SE2 Sell']

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(20, 10), dpi=80, facecolor='w', edgecolor='k')

plt.plot(X,SE2_Buy)
plt.plot(X,SE2_Sell)

# %%
SE3_Buy = df['SE3 Buy']
SE3_Sell = df['SE3 Sell']

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(20, 10), dpi=80, facecolor='w', edgecolor='k')

plt.plot(X,SE3_Buy)
plt.plot(X,SE3_Sell)

# %%
SE4_Buy = df['SE4 Buy']
SE4_Sell = df['SE4 Sell']

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(20, 10), dpi=80, facecolor='w', edgecolor='k')

plt.plot(X,SE4_Buy)
plt.plot(X,SE4_Sell)
