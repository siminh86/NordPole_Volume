# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Importing 365 days in a year
df_date = pd.read_excel("DateInOneYear.xlsx",sheetname='2013', header=None)
RevisedDate = df_date[0]
RevisedDate.shape
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\excel.py:329: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   **kwds)
# (365,)

# %%
df = pd.read_excel("01. elspot-volumes_2013_daily.xlsx")
df['Date_daily'] = RevisedDate
df.tail(5)
# Out:
#     Date_daily Turnover at system price   NO1 Buy NO1 Sell   NO2 Buy  \
# 360 2013-12-27                 958768,3  106830,0  42487,8  105293,2
# 361 2013-12-28                 905696,4   92029,7  39191,9  105272,4
# 362 2013-12-29                 922395,6   94641,5  42629,4  104430,0
# 363 2013-12-30                 988834,0  110361,4  43515,4  105809,3
# 364 2013-12-31                 930576,5  101419,1  41733,0  100908,5
#
#      NO2 Sell  NO3 Buy NO3 Sell  NO4 Buy NO4 Sell   ...     DK2 Buy DK2 Sell  \
# 360  118837,9  57296,2  38173,3  47802,9  62330,0   ...     35611,0  39538,0
# 361  104217,9  55586,0  32774,5  45902,6  54906,0   ...     36882,3  30490,5
# 362  102945,0  55841,8  36381,5  45491,0  58748,9   ...     39512,4  31253,7
# 363  121672,6  58272,8  36805,9  47721,9  64217,1   ...     40847,8  32835,4
# 364  109535,9  56313,4  34310,2  46382,7  60791,8   ...     37019,0  28386,6
#
#       EE Buy  EE Sell ELE Buy ELE Sell  LV Buy LV Sell   LT Buy  LT Sell
# ...

# %%
df.shape
# Out:
# (365, 34)

# %%
X = df['Date_daily']
SE1_Buy = df['SE1 Buy']
SE1_Sell = df['SE1 Sell']

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(20, 10), dpi=80, facecolor='w', edgecolor='k')

plt.plot(X,SE1_Buy)
plt.plot(X,SE1_Sell)

# %%
SE2_Buy = df['SE2 Buy']
SE2_Sell = df['SE2 Sell']

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(20, 10), dpi=80, facecolor='w', edgecolor='k')

plt.plot(X,SE2_Buy)
plt.plot(X,SE2_Sell)

# %%
SE3_Buy = df['SE3 Buy']
SE3_Sell = df['SE3 Sell']

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(20, 10), dpi=80, facecolor='w', edgecolor='k')

plt.plot(X,SE3_Buy)
plt.plot(X,SE3_Sell)

# %%
SE4_Buy = df['SE4 Buy']
SE4_Sell = df['SE4 Sell']

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(20, 10), dpi=80, facecolor='w', edgecolor='k')

plt.plot(X,SE4_Buy)
plt.plot(X,SE4_Sell)

# %%
SE_Buy = range ('SE1 Buy', 'SE4 Buy')
SE_Sell = range ('SE1 Sell', 'SE4 Sell')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-e8158dfa2a5f> in <module>()
# ----> 1 SE_Buy = range ('SE1 Buy', 'SE4 Buy')
#       2 SE_Sell = range ('SE1 Sell', 'SE4 Sell')
#
# TypeError: 'str' object cannot be interpreted as an integer

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(20, 10), dpi=80, facecolor='w', edgecolor='k')

plt.plot(X,Y1)
plt.plot(X,Y2)
