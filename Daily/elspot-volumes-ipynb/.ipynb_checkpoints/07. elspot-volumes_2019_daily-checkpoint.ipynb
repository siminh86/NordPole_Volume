# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('C:/Users/simhaj-local/Documents/GitHub/NordPool/Daily/CSVFiles/07. elspot-volumes_2019_daily.csv')

# %%
df.shape
# Out:
# (174, 33)

# %%
df['DateAndTime'] = pd.date_range('1/1/2019', periods=174, freq='D')

# %%
SE1_Buy = df['SE1 Buy']
SE1_Sell = df['SE1 Sell']

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(20, 10), dpi=80, facecolor='w', edgecolor='k')

plt.xlabel('2019-Day')
plt.ylabel('Amount')
plt.title('2019 Sell and Buy')


plt.plot(df.DateAndTime,SE1_Buy)
plt.plot(df.DateAndTime,SE1_Sell)

plt.legend(loc='upper left')

# %%
SE2_Buy = df['SE2 Buy']
SE2_Sell = df['SE2 Sell']

# %%
figure(num=None, figsize=(20, 10), dpi=80, facecolor='w', edgecolor='k')

plt.xlabel('2019-Day')
plt.ylabel('Amount')
plt.title('2019 Sell and Buy')


plt.plot(df.DateAndTime,SE2_Buy)
plt.plot(df.DateAndTime,SE2_Sell)

plt.legend(loc='upper left')

# %%
SE3_Buy = df['SE3 Buy']
SE3_Sell = df['SE3 Sell']

# %%
figure(num=None, figsize=(20, 10), dpi=80, facecolor='w', edgecolor='k')

plt.xlabel('2019-Day')
plt.ylabel('Amount')
plt.title('2019 Sell and Buy')


plt.plot(df.DateAndTime,SE3_Buy)
plt.plot(df.DateAndTime,SE3_Sell)

plt.legend(loc='upper left')

# %%
SE4_Buy = df['SE4 Buy']
SE4_Sell = df['SE4 Sell']

# %%
figure(num=None, figsize=(20, 10), dpi=80, facecolor='w', edgecolor='k')

plt.xlabel('2019-Day')
plt.ylabel('Amount')
plt.title('2019 Sell and Buy')


plt.plot(df.DateAndTime,SE4_Buy)
plt.plot(df.DateAndTime,SE4_Sell)

plt.legend(loc='upper left')
