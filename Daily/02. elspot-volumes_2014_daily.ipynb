# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Importing 365 days in a year
df_date = pd.read_excel("DateInOneYear.xlsx", header=None)
RevisedDate = df_date[0]
RevisedDate.shape
# Out:
# (365,)

# %%
df = pd.read_excel("02. elspot-volumes_2014_daily.xlsx")
df['Date_daily'] = RevisedDate
df.tail(5)
# Out:
#     Elspot volumes in MWh Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 362            27-12-2014  1143994,3   146792,3    53331,5   121475,7
# 363            28-12-2014  1177521,7   144006,2    53876,5   121737,5
# 364            29-12-2014  1243569,2   149704,3    59212,9   129679,1
# 365            30-12-2014  1180037,5   147228,4    57075,2   131267,1
# 366            31-12-2014  1047169,1   133623,2    54341,3   122123,1
#
#     Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9    ...      \
# 362   198308,9    69647,0    39191,4    52094,0    73092,9    ...
# 363   208104,7    67469,0    43271,2    51632,9    77202,2    ...
# 364   209273,8    66397,0    53685,6    53345,6    83456,6    ...
# 365   198752,3    65383,4    48281,8    50433,9    70271,2    ...
# 366   166298,9    60145,5    37617,2    47142,6    47815,5    ...
#
#     Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26 Unnamed: 27 Unnamed: 28  \
# ...

# %%
df.shape
# Out:
# (367, 33)

# %%
X = df['Date_daily']
Y1 = df['SE1 Buy']
Y2 = df['SE1 Sell']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SE1 Buy'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-cccbb06b8d77> in <module>()
#       1 X = df['Date_daily']
# ...
