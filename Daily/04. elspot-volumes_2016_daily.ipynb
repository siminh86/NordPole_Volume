# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Importing 365 days in a year
df_date = pd.read_excel("DateInOneYear.xlsx",sheetname='2016', header=None)
RevisedDate = df_date[0]
RevisedDate.shape
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\excel.py:329: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   **kwds)
# (366,)

# %%
df = pd.read_excel("04. elspot-volumes_2016_daily.xlsx", header = 2, parse_dates=True)
df['Date_daily'] = RevisedDate
df.head(5)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\excel.py:520: UserWarning: The 'parse_dates=True' keyword of read_excel was provided without an 'index_col' keyword value.
#   warn("The 'parse_dates=True' keyword of read_excel was provided"
#            Turnover at system price   NO1 Buy NO1 Sell   NO2 Buy  NO2 Sell  \
# 2016-01-01                1048265,1  114231,7  43086,6  114365,9  191842,1
# 2016-02-01                1084366,7  121832,7  37478,1  114496,4  173718,9
# 2016-03-01                1138632,6  132963,1  45420,4  121323,6  182840,0
# 2016-04-01                1291483,8  153509,4  47299,8  131933,3  205951,6
# 2016-05-01                1324801,8  154210,1  48895,2  137612,9  217619,5
#
#             NO3 Buy NO3 Sell  NO4 Buy NO4 Sell  NO5 Buy    ...     DK1 Sell  \
# 2016-01-01  60028,8  37169,2  45714,0  54285,7  58792,4    ...      31778,1
# 2016-02-01  66327,3  31918,4  47207,8  45221,8  60824,1    ...      81358,3
# ...

# %%
df.shape
# Out:
# (366, 34)

# %%
X = RevisedDate
SE1_Buy = df['SE1 Buy']
SE1_Sell = df['SE1 Sell']

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(20, 10), dpi=80, facecolor='w', edgecolor='k')

plt.xlabel('2016-Day')
plt.ylabel('Amount')
plt.title('2016 Sell and Buy')


plt.plot(X,SE1_Buy)
plt.plot(X,SE1_Sell)

plt.legend(loc='upper left')

# %%
SE2_Buy = df['SE2 Buy']
SE2_Sell = df['SE2 Sell']

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(20, 10), dpi=80, facecolor='w', edgecolor='k')

plt.plot(X,SE2_Buy)
plt.plot(X,SE2_Sell)

# %%
SE3_Buy = df['SE3 Buy']
SE3_Sell = df['SE3 Sell']

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(20, 10), dpi=80, facecolor='w', edgecolor='k')

plt.plot(X,SE3_Buy)
plt.plot(X,SE3_Sell)

# %%
SE4_Buy = df['SE4 Buy']
SE4_Sell = df['SE4 Sell']

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(20, 10), dpi=80, facecolor='w', edgecolor='k')

plt.plot(X,SE4_Buy)
plt.plot(X,SE4_Sell)
