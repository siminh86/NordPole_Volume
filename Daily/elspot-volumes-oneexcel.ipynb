# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Importing 365 days in a year
df_date = pd.read_excel("DateInOneYear.xlsx",header=None)
RevisedDate = df_date[0]
RevisedDate.shape

# %%
df = pd.read_excel("elspot-volumes-oneexcel.xlsx")
df['Date_daily'] = RevisedDate

# %%
df.shape

# %%
X = df['Date_daily']
SE1_Buy = df['SE1 Buy']
SE1_Sell = df['SE1 Sell']

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(20, 10), dpi=80, facecolor='w', edgecolor='k')

plt.plot(X,SE1_Buy)
plt.plot(X,SE1_Sell)

# %%
SE2_Buy = df['SE2 Buy']
SE2_Sell = df['SE2 Sell']

SE3_Buy = df['SE3 Buy']
SE3_Sell = df['SE3 Sell']

SE4_Buy = df['SE4 Buy']
SE4_Sell = df['SE4 Sell']

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(20, 10), dpi=80, facecolor='w', edgecolor='k')

plt.plot(X,SE2_Buy,SE3_Buy,SE4_Buy)
plt.plot(X,SE2_Sell,SE3_Sell,SE4_Sell)
# Out:
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py", line 387, in process
#     proxy(*args, **kwargs)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py", line 227, in __call__
#     return mtd(*args, **kwargs)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\lines.py", line 647, in recache_always
#     self.recache(always=True)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\lines.py", line 651, in recache
#     xconv = self.convert_xunits(self._xorig)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\artist.py", line 191, in convert_xunits
#     return ax.xaxis.convert_units(x)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axis.py", line 1526, in convert_units
#     ret = self.converter.convert(x, self.units, self)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\category.py", line 65, in convert
#     unit.update(values)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\category.py", line 201, in update
#     raise TypeError("{val!r} is not a string".format(val=val))
# TypeError: 1356998400000000000 is not a string
# [<matplotlib.lines.Line2D at 0x26fa5c51630>,
#  <matplotlib.lines.Line2D at 0x26fa5d50ac8>]
